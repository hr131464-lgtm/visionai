# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
file_path = "D:/visionai/notebook/Cleaned_Merged_Aneurysm.csv"
df = pd.read_csv(file_path)

# Remove columns with at least one null value
cleaned_df = df.dropna(axis=1, how='any')

# Save the cleaned dataset to a new CSV file
# cleaned_file_path = "Cleaned_Merged_Aneurysm.csv"
# cleaned_df.to_csv(cleaned_file_path, index=False)

# print(f"Columns with null values removed. Cleaned data saved to {cleaned_file_path}")

# %%
df.head()
# Out:
#   case_id patient_id aneurysmLocation aneurysmType ruptureStatus  age sex  \
# 0   C0001      P0085              ICA          LAT             U   53   F
# 1   C0002      P0112              ICA          LAT             U   35   F
# 2   C0003      P0115              ICA          TER             U   43   F
# 3   C0004      P0116              ICA          TER             U   60   F
# 4   C0005      P0118              ICA          LAT             R   26   F
#
#    multipleAneurysms   sacVolume  sacSurfaceArea  ...  meanRadius  \
# 0              False  125.259604      120.453515  ...    1.698477
# 1              False  119.002032      122.427263  ...    1.876690
# 2              False   12.740609       23.480617  ...    1.694932
# 3               True    9.376307       18.084625  ...    1.646903
# 4              False   37.934454       54.844592  ...    1.331788
#
#    meanCurvature  meanTorsion  tortuosity  minRadius  maxRadius  maxCurvature  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     case_id patient_id aneurysmLocation aneurysmType ruptureStatus  age sex  \
# 0     C0001      P0085              ICA          LAT             U   53   F
# 1     C0002      P0112              ICA          LAT             U   35   F
# 2     C0003      P0115              ICA          TER             U   43   F
# 3     C0004      P0116              ICA          TER             U   60   F
# 4     C0005      P0118              ICA          LAT             R   26   F
# ..      ...        ...              ...          ...           ...  ...  ..
# 98    C0095      P0270              BAS          TER             U   43   F
# 99    C0096      P0271              BAS          TER             R   67   M
# 100   C0097      P0274              ICA          LAT             R   84   F
# 101   C0098      P0286              MCA          TER             R   59   F
# 102   C0099      P0288              MCA          TER             U   42   F
#
# ...

# %%
df.describe()
# Out:
#               age    sacVolume  sacSurfaceArea    vdcVolume  vdcSurfaceArea  \
# count  103.000000   103.000000      103.000000   103.000000      103.000000
# mean    54.572816   207.726978      145.022975   187.990480      129.519595
# std     13.779497   279.394028      133.633109   255.272818      119.365392
# min     24.000000     2.339496        7.333407     2.121879        6.495522
# 25%     43.000000    38.104803       51.113444    35.284619       49.519521
# 50%     55.000000    92.021799       92.777085    86.406187       83.265224
# 75%     64.500000   274.308487      203.174499   245.624382      176.754502
# max     85.000000  1312.025948      625.717664  1223.412403      583.439703
#
#        sacSectionArea  sacCenterlineLength  ostiumSectionArea  \
# count      103.000000           103.000000         103.000000
# mean        31.697933             6.566324          19.101930
# std         28.937416             3.060525          13.855157
# ...

# %%
df.isnull().sum()
# Out:
# case_id                       0
# patient_id                    0
# aneurysmLocation              0
# aneurysmType                  0
# ruptureStatus                 0
# age                           0
# sex                           0
# multipleAneurysms             0
# sacVolume                     0
# sacSurfaceArea                0
# vdcVolume                     0
# vdcSurfaceArea                0
# sacSectionArea                0
# sacCenterlineLength           0
# ostiumSectionArea             0
# ostiumSectionPerimeter        0
# ostiumMinSize                 0
# ostiumMaxSize                 0
# ostiumShapeFactor             0
# aspectRatio_star              0
# sizeRatio_star                0
# vesselDiameter                0
# neckVesselAngle               0
# sacVesselAngle                0
# vesselName                    0
# length                        0
# meanRadius                    0
# meanCurvature                 0
# meanTorsion                   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   case_id                     103 non-null    object
#  1   patient_id                  103 non-null    object
#  2   aneurysmLocation            103 non-null    object
#  3   aneurysmType                103 non-null    object
#  4   ruptureStatus               103 non-null    object
#  5   age                         103 non-null    int64
#  6   sex                         103 non-null    object
#  7   multipleAneurysms           103 non-null    bool
#  8   sacVolume                   103 non-null    float64
#  9   sacSurfaceArea              103 non-null    float64
#  10  vdcVolume                   103 non-null    float64
#  11  vdcSurfaceArea              103 non-null    float64
#  12  sacSectionArea              103 non-null    float64
# ...

# %%
df.drop(['case_id','patient_id'],axis=1,inplace=True)

# %%
df
# Out:
#     aneurysmLocation aneurysmType ruptureStatus  age sex  multipleAneurysms  \
# 0                ICA          LAT             U   53   F              False
# 1                ICA          LAT             U   35   F              False
# 2                ICA          TER             U   43   F              False
# 3                ICA          TER             U   60   F               True
# 4                ICA          LAT             R   26   F              False
# ..               ...          ...           ...  ...  ..                ...
# 98               BAS          TER             U   43   F              False
# 99               BAS          TER             R   67   M              False
# 100              ICA          LAT             R   84   F              False
# 101              MCA          TER             R   59   F              False
# 102              MCA          TER             U   42   F              False
#
# ...

# %%
df['aneurysmLocation'].unique()
# Out:
# array(['ICA', 'ACA', 'MCA', 'BAS'], dtype=object)

# %% [markdown]
# In the context of multiple aneurysms, ICA refers to the Internal Carotid Artery, ACA to the Anterior Cerebral Artery, MCA to the Middle Cerebral Artery, and BAS to the Basilar Artery, all of which are major arteries in the brain where aneurysms can occur.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
df['aneurysmLocation_encoded'] = label_encoder.fit_transform(df['aneurysmLocation'])

# %%
df.head()
# Out:
#   aneurysmLocation aneurysmType ruptureStatus  age sex  multipleAneurysms  \
# 0              ICA          LAT             U   53   F              False
# 1              ICA          LAT             U   35   F              False
# 2              ICA          TER             U   43   F              False
# 3              ICA          TER             U   60   F               True
# 4              ICA          LAT             R   26   F              False
#
#     sacVolume  sacSurfaceArea   vdcVolume  vdcSurfaceArea  ...  meanCurvature  \
# 0  125.259604      120.453515  111.237957      106.759273  ...       0.149981
# 1  119.002032      122.427263  113.720361      115.774279  ...       0.171728
# 2   12.740609       23.480617   11.865511       21.853480  ...       0.154458
# 3    9.376307       18.084625    9.031234       17.295395  ...       0.135058
# 4   37.934454       54.844592   35.903048       52.303479  ...       0.125326
#
# ...

# %% [markdown]
# ICA->2, BAS->1, MCA->3 ,ACA->0

# %%
df.drop('aneurysmLocation',axis=1,inplace=True)

# %%
df.head()
# Out:
#   aneurysmType ruptureStatus  age sex  multipleAneurysms   sacVolume  \
# 0          LAT             U   53   F              False  125.259604
# 1          LAT             U   35   F              False  119.002032
# 2          TER             U   43   F              False   12.740609
# 3          TER             U   60   F               True    9.376307
# 4          LAT             R   26   F              False   37.934454
#
#    sacSurfaceArea   vdcVolume  vdcSurfaceArea  sacSectionArea  ...  \
# 0      120.453515  111.237957      106.759273       21.938237  ...
# 1      122.427263  113.720361      115.774279       18.493788  ...
# 2       23.480617   11.865511       21.853480        6.142748  ...
# 3       18.084625    9.031234       17.295395        4.905063  ...
# 4       54.844592   35.903048       52.303479        9.729065  ...
#
#    meanCurvature  meanTorsion  tortuosity  minRadius  maxRadius  maxCurvature  \
# ...

# %%
df['aneurysmType'].unique()
# Out:
# array(['LAT', 'TER'], dtype=object)

# %% [markdown]
# In the context of multiple aneurysms, LAT refers to lateral aneurysms located on the outer side of arteries, while TER refers to terminal aneurysms located at the bifurcation or end of an artery.

# %%
df['aneurysmType_encoded'] = label_encoder.fit_transform(df['aneurysmType'])

# %% [markdown]
# LAT->0,TER->1 (by default it labels alphabetically)

# %%
df.drop('aneurysmType',axis=1,inplace=True)

# %%
df.head()
# Out:
#   ruptureStatus  age sex  multipleAneurysms   sacVolume  sacSurfaceArea  \
# 0             U   53   F              False  125.259604      120.453515
# 1             U   35   F              False  119.002032      122.427263
# 2             U   43   F              False   12.740609       23.480617
# 3             U   60   F               True    9.376307       18.084625
# 4             R   26   F              False   37.934454       54.844592
#
#     vdcVolume  vdcSurfaceArea  sacSectionArea  sacCenterlineLength  ...  \
# 0  111.237957      106.759273       21.938237             6.510948  ...
# 1  113.720361      115.774279       18.493788             8.160692  ...
# 2   11.865511       21.853480        6.142748             2.687731  ...
# 3    9.031234       17.295395        4.905063             2.065733  ...
# 4   35.903048       52.303479        9.729065             5.299550  ...
#
#    meanTorsion  tortuosity  minRadius  maxRadius  maxCurvature  maxTorsion  \
# ...

# %%
df['ruptureStatus'].unique()
# Out:
# array(['U', 'R'], dtype=object)

# %% [markdown]
# In the context of multiple aneurysms, U likely refers to unruptured aneurysms, and R refers to ruptured aneurysms.

# %%
df['ruptureStatus_encoded'] = label_encoder.fit_transform(df['ruptureStatus'])

# %% [markdown]
# R->0,U->1

# %%
df.drop('ruptureStatus',axis=1,inplace=True)

# %%
df.head()
# Out:
#    age sex  multipleAneurysms   sacVolume  sacSurfaceArea   vdcVolume  \
# 0   53   F              False  125.259604      120.453515  111.237957
# 1   35   F              False  119.002032      122.427263  113.720361
# 2   43   F              False   12.740609       23.480617   11.865511
# 3   60   F               True    9.376307       18.084625    9.031234
# 4   26   F              False   37.934454       54.844592   35.903048
#
#    vdcSurfaceArea  sacSectionArea  sacCenterlineLength  ostiumSectionArea  \
# 0      106.759273       21.938237             6.510948          15.769098
# 1      115.774279       18.493788             8.160692          16.211407
# 2       21.853480        6.142748             2.687731           6.788978
# 3       17.295395        4.905063             2.065733           7.310342
# 4       52.303479        9.729065             5.299550           6.904112
#
#    ...  tortuosity  minRadius  maxRadius  maxCurvature  maxTorsion  \
# ...

# %%
df['sex_encoded'] = label_encoder.fit_transform(df['sex'])

# %%
df.drop('sex',axis=1,inplace=True)

# %%
df['multipleAneurysms_encoded'] = label_encoder.fit_transform(df['multipleAneurysms'])

# %%
df.drop('multipleAneurysms',axis=1,inplace=True)

# %%
df.head()
# Out:
#    age   sacVolume  sacSurfaceArea   vdcVolume  vdcSurfaceArea  \
# 0   53  125.259604      120.453515  111.237957      106.759273
# 1   35  119.002032      122.427263  113.720361      115.774279
# 2   43   12.740609       23.480617   11.865511       21.853480
# 3   60    9.376307       18.084625    9.031234       17.295395
# 4   26   37.934454       54.844592   35.903048       52.303479
#
#    sacSectionArea  sacCenterlineLength  ostiumSectionArea  \
# 0       21.938237             6.510948          15.769098
# 1       18.493788             8.160692          16.211407
# 2        6.142748             2.687731           6.788978
# 3        4.905063             2.065733           7.310342
# 4        9.729065             5.299550           6.904112
#
#    ostiumSectionPerimeter  ostiumMinSize  ...  maxRadius  maxCurvature  \
# 0               14.523258       1.875647  ...   2.092899      0.513167
# 1               14.616704       2.011954  ...   2.629028      0.532819
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         103 non-null    int64
#  1   sacVolume                   103 non-null    float64
#  2   sacSurfaceArea              103 non-null    float64
#  3   vdcVolume                   103 non-null    float64
#  4   vdcSurfaceArea              103 non-null    float64
#  5   sacSectionArea              103 non-null    float64
#  6   sacCenterlineLength         103 non-null    float64
#  7   ostiumSectionArea           103 non-null    float64
#  8   ostiumSectionPerimeter      103 non-null    float64
#  9   ostiumMinSize               103 non-null    float64
#  10  ostiumMaxSize               103 non-null    float64
#  11  ostiumShapeFactor           103 non-null    float64
#  12  aspectRatio_star            103 non-null    float64
# ...

# %%
df.drop('vesselName',axis=1,inplace=True)

# %%
df.head()
# Out:
#    age   sacVolume  sacSurfaceArea   vdcVolume  vdcSurfaceArea  \
# 0   53  125.259604      120.453515  111.237957      106.759273
# 1   35  119.002032      122.427263  113.720361      115.774279
# 2   43   12.740609       23.480617   11.865511       21.853480
# 3   60    9.376307       18.084625    9.031234       17.295395
# 4   26   37.934454       54.844592   35.903048       52.303479
#
#    sacSectionArea  sacCenterlineLength  ostiumSectionArea  \
# 0       21.938237             6.510948          15.769098
# 1       18.493788             8.160692          16.211407
# 2        6.142748             2.687731           6.788978
# 3        4.905063             2.065733           7.310342
# 4        9.729065             5.299550           6.904112
#
#    ostiumSectionPerimeter  ostiumMinSize  ...  maxRadius  maxCurvature  \
# 0               14.523258       1.875647  ...   2.092899      0.513167
# 1               14.616704       2.011954  ...   2.629028      0.532819
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         103 non-null    int64
#  1   sacVolume                   103 non-null    float64
#  2   sacSurfaceArea              103 non-null    float64
#  3   vdcVolume                   103 non-null    float64
#  4   vdcSurfaceArea              103 non-null    float64
#  5   sacSectionArea              103 non-null    float64
#  6   sacCenterlineLength         103 non-null    float64
#  7   ostiumSectionArea           103 non-null    float64
#  8   ostiumSectionPerimeter      103 non-null    float64
#  9   ostiumMinSize               103 non-null    float64
#  10  ostiumMaxSize               103 non-null    float64
#  11  ostiumShapeFactor           103 non-null    float64
#  12  aspectRatio_star            103 non-null    float64
# ...

# %%
df.corr()
# Out:
#                                  age  sacVolume  sacSurfaceArea  vdcVolume  \
# age                         1.000000   0.181444        0.203610   0.167348
# sacVolume                   0.181444   1.000000        0.980898   0.995068
# sacSurfaceArea              0.203610   0.980898        1.000000   0.966948
# vdcVolume                   0.167348   0.995068        0.966948   1.000000
# vdcSurfaceArea              0.178993   0.982226        0.985416   0.984681
# sacSectionArea              0.179735   0.959565        0.962082   0.956524
# sacCenterlineLength         0.181168   0.852236        0.907820   0.850967
# ostiumSectionArea           0.238017   0.583807        0.596474   0.582067
# ostiumSectionPerimeter      0.248182   0.569698        0.594428   0.565645
# ostiumMinSize               0.229189   0.568583        0.580423   0.580713
# ostiumMaxSize               0.231272   0.537720        0.562647   0.531513
# ...

# %% [markdown]
# From the correlation table, we analyze the correlation between multipleAneurysms_encoded and other features:
#
# Features with Higher Correlation:
#
# -> ruptureStatus_encoded (0.225):
# Reason: Aneurysms that rupture could be more likely to occur alongside multiple aneurysms, suggesting a possible physiological relationship.
#
# -> aneurysmLocation_encoded (0.212):
# Reason: Certain locations in the vasculature might be more prone to multiple aneurysms due to structural or biomechanical stress.
#
# -> aneurysmType_encoded (-0.075):
# Reason: The type of aneurysm may influence whether multiple aneurysms are present, as some types may occur due to systemic issues affecting the vascular structure.
#
# -> bifurcationAngleOutOfPlane (0.175):
# Reason: Bifurcation geometry affects hemodynamic stress, potentially influencing the formation of multiple aneurysms.
#
# -> sacVolume (-0.044):
# Reason: Larger aneurysms could indicate chronic hemodynamic stresses, which might correlate with the presence of multiple aneurysms.
#
# -> sex_encoded (-0.068):
# Reason: Biological sex differences in vascular structure and hemodynamics could play a role in aneurysm formation patterns.
#
# => Final Feature Importance Decision
#
# Strong Predictors:-
# ruptureStatus_encoded
# aneurysmLocation_encoded
# aneurysmType_encoded
# bifurcationAngleOutOfPlane
# Moderate Predictors:
# sex_encoded
# sacVolume

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['age', 'sacVolume', 'sacSurfaceArea', 'vdcVolume', 'vdcSurfaceArea',
#        'sacSectionArea', 'sacCenterlineLength', 'ostiumSectionArea',
#        'ostiumSectionPerimeter', 'ostiumMinSize', 'ostiumMaxSize',
#        'ostiumShapeFactor', 'aspectRatio_star', 'sizeRatio_star',
#        'vesselDiameter', 'neckVesselAngle', 'sacVesselAngle', 'length',
#        'meanRadius', 'meanCurvature', 'meanTorsion', 'tortuosity', 'minRadius',
#        'maxRadius', 'maxCurvature', 'maxTorsion', 'bifurcationAngleInPlane',
#        'bifurcationAngleOutOfPlane', 'aneurysmLocation_encoded',
#        'aneurysmType_encoded', 'ruptureStatus_encoded', 'sex_encoded',
#        'multipleAneurysms_encoded'],
#       dtype='object')

# %%
df.drop('bifurcationAngleInPlane',axis=1,inplace=True)

# %%
df.drop('sacCenterlineLength',axis=1,inplace=True)

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Highly positive correlated->raptureStatus_encoded,aneurysmLocation_encoded,bifurcationAngleOutOfPlane,maxTorsion,tortuosity,neckvesselangle,age,aneurysmType_encoded,ostiumShapeFactor,multipleAneurysms_encoded,maxCurvature

# %%
df.columns
# Out:
# Index(['age', 'sacVolume', 'sacSurfaceArea', 'vdcVolume', 'vdcSurfaceArea',
#        'sacSectionArea', 'ostiumSectionArea', 'ostiumSectionPerimeter',
#        'ostiumMinSize', 'ostiumMaxSize', 'ostiumShapeFactor',
#        'aspectRatio_star', 'sizeRatio_star', 'vesselDiameter',
#        'neckVesselAngle', 'sacVesselAngle', 'length', 'meanRadius',
#        'meanCurvature', 'meanTorsion', 'tortuosity', 'minRadius', 'maxRadius',
#        'maxCurvature', 'maxTorsion', 'bifurcationAngleOutOfPlane',
#        'aneurysmLocation_encoded', 'aneurysmType_encoded',
#        'ruptureStatus_encoded', 'sex_encoded', 'multipleAneurysms_encoded'],
#       dtype='object')

# %%
# List of desired features
selected_features = [
    'ruptureStatus_encoded',
    'aneurysmLocation_encoded',
    'bifurcationAngleOutOfPlane',
    'maxTorsion',
    'tortuosity',
    'neckVesselAngle',
    'age',
    'aneurysmType_encoded',
    'ostiumShapeFactor',
    'maxCurvature',
    'multipleAneurysms_encoded'
    
]

new_df = df[selected_features]

print(new_df.head())
# Out:
#    ruptureStatus_encoded  aneurysmLocation_encoded  \
# 0                      1                         2
# 1                      1                         2
# 2                      1                         2
# 3                      1                         2
# 4                      0                         2
#
#    bifurcationAngleOutOfPlane  maxTorsion  tortuosity  neckVesselAngle  age  \
# 0                    4.719235    3.218984    0.682769        42.579274   53
# 1                   15.753911    5.330711    1.153133        84.077789   35
# 2                    9.378066    3.393943    0.804790        43.969651   43
# 3                   27.053597    5.385147    0.837999        39.771392   60
# 4                   23.284114    8.852139    0.548677        60.026682   26
#
#    aneurysmType_encoded  ostiumShapeFactor  maxCurvature  \
# 0                     0           0.677545      0.513167
# 1                     0           0.754575      0.532819
# ...

# %%
new_df.head()
# Out:
#    ruptureStatus_encoded  aneurysmLocation_encoded  \
# 0                      1                         2
# 1                      1                         2
# 2                      1                         2
# 3                      1                         2
# 4                      0                         2
#
#    bifurcationAngleOutOfPlane  maxTorsion  tortuosity  neckVesselAngle  age  \
# 0                    4.719235    3.218984    0.682769        42.579274   53
# 1                   15.753911    5.330711    1.153133        84.077789   35
# 2                    9.378066    3.393943    0.804790        43.969651   43
# 3                   27.053597    5.385147    0.837999        39.771392   60
# 4                   23.284114    8.852139    0.548677        60.026682   26
#
#    aneurysmType_encoded  ostiumShapeFactor  maxCurvature  \
# 0                     0           0.677545      0.513167
# 1                     0           0.754575      0.532819
# ...

# %%
new_df.corr()
# Out:
#                             ruptureStatus_encoded  aneurysmLocation_encoded  \
# ruptureStatus_encoded                    1.000000                  0.337252
# aneurysmLocation_encoded                 0.337252                  1.000000
# bifurcationAngleOutOfPlane              -0.062872                 -0.163522
# maxTorsion                               0.101466                  0.014775
# tortuosity                               0.278148                  0.191497
# neckVesselAngle                          0.155995                  0.266738
# age                                     -0.036922                  0.012820
# aneurysmType_encoded                    -0.245140                 -0.207130
# ostiumShapeFactor                        0.189645                  0.101538
# maxCurvature                             0.234375                  0.141396
# multipleAneurysms_encoded                0.225340                  0.212158
#
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(new_df.corr(),annot=True)
# Out:
# <Axes: >

# %%
new_df.shape
# Out:
# (103, 11)

# %%
df.shape
# Out:
# (103, 31)

# %%
y=new_df['multipleAneurysms_encoded']

# %%
new_df.drop('multipleAneurysms_encoded',axis=1,inplace=True)

# %%
X=new_df

# %%
X
# Out:
#      ruptureStatus_encoded  aneurysmLocation_encoded  \
# 0                        1                         2
# 1                        1                         2
# 2                        1                         2
# 3                        1                         2
# 4                        0                         2
# ..                     ...                       ...
# 98                       1                         1
# 99                       0                         1
# 100                      0                         2
# 101                      0                         3
# 102                      1                         3
#
#      bifurcationAngleOutOfPlane  maxTorsion  tortuosity  neckVesselAngle  age  \
# 0                      4.719235    3.218984    0.682769        42.579274   53
# 1                     15.753911    5.330711    1.153133        84.077789   35
# 2                      9.378066    3.393943    0.804790        43.969651   43
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 98     0
# 99     0
# 100    0
# 101    0
# 102    0
# Name: multipleAneurysms_encoded, Length: 103, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train
# Out:
#      ruptureStatus_encoded  aneurysmLocation_encoded  \
# 15                       1                         2
# 73                       1                         3
# 39                       1                         2
# 9                        1                         0
# 84                       0                         0
# ..                     ...                       ...
# 71                       1                         3
# 14                       0                         2
# 92                       1                         2
# 51                       0                         3
# 102                      1                         3
#
#      bifurcationAngleOutOfPlane  maxTorsion  tortuosity  neckVesselAngle  age  \
# 15                    32.129174   10.691176    0.567643        50.902025   42
# 73                    39.719586    0.883419    0.021532        60.556205   72
# 39                    19.938293  162.847544    1.185035        21.873820   59
# ...

# %%
X_train.shape
# Out:
# (77, 10)

# %%
X_test.shape
# Out:
# (26, 10)

# %%
y_train.shape
# Out:
# (77,)

# %%
y_test.shape
# Out:
# (26,)

# %%
X
# Out:
#      ruptureStatus_encoded  aneurysmLocation_encoded  \
# 0                        1                         2
# 1                        1                         2
# 2                        1                         2
# 3                        1                         2
# 4                        0                         2
# ..                     ...                       ...
# 98                       1                         1
# 99                       0                         1
# 100                      0                         2
# 101                      0                         3
# 102                      1                         3
#
#      bifurcationAngleOutOfPlane  maxTorsion  tortuosity  neckVesselAngle  age  \
# 0                      4.719235    3.218984    0.682769        42.579274   53
# 1                     15.753911    5.330711    1.153133        84.077789   35
# 2                      9.378066    3.393943    0.804790        43.969651   43
# ...

# %%
# Save new_df as a CSV file
new_df.to_csv('new_df.csv', index=False)

print("CSV file saved successfully!")
# Out:
# CSV file saved successfully!

# %%
# Save new_df as a CSV file
y.to_csv('y.csv', index=False)

print("CSV file saved successfully!")
# Out:
# CSV file saved successfully!

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 98     0
# 99     0
# 100    0
# 101    0
# 102    0
# Name: multipleAneurysms_encoded, Length: 103, dtype: int64

# %%
y.dtype
# Out:
# dtype('int64')

# %%
y=pd.DataFrame(y)

# %%
y
# Out:
#      multipleAneurysms_encoded
# 0                            0
# 1                            0
# 2                            0
# 3                            1
# 4                            0
# ..                         ...
# 98                           0
# 99                           0
# 100                          0
# 101                          0
# 102                          0
#
# [103 rows x 1 columns]

# %%
new_df
# Out:
#      ruptureStatus_encoded  aneurysmLocation_encoded  \
# 0                        1                         2
# 1                        1                         2
# 2                        1                         2
# 3                        1                         2
# 4                        0                         2
# ..                     ...                       ...
# 98                       1                         1
# 99                       0                         1
# 100                      0                         2
# 101                      0                         3
# 102                      1                         3
#
#      bifurcationAngleOutOfPlane  maxTorsion  tortuosity  neckVesselAngle  age  \
# 0                      4.719235    3.218984    0.682769        42.579274   53
# 1                     15.753911    5.330711    1.153133        84.077789   35
# 2                      9.378066    3.393943    0.804790        43.969651   43
# ...
